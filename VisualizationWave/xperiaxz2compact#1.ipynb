# %% [markdown]
# # Xperia XZ2 Compact #1 Visualization

# %% [markdown]
# ## Premise
# *Comparison method*：Measure for 15 seconds.
# *Proposed method*：Measure for 15 seconds and **filter during USB PD negotiation period.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
xperiaxz2compact_15s_soc10_home_1 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_home_train_1.csv')
xperiaxz2compact_15s_soc10_home_2 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_home_train_2.csv')
xperiaxz2compact_15s_soc10_home_3 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_home_train_3.csv')
xperiaxz2compact_15s_soc10_home_4 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_home_train_4.csv')
xperiaxz2compact_15s_soc10_home_5 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_home_train_5.csv')

xperiaxz2compact_15s_soc10_home = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_home_train_1.csv')
xperiaxz2compact_15s_soc10_game = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_game_train_1.csv')
xperiaxz2compact_15s_soc10_sns = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_sns_train_1.csv')
xperiaxz2compact_15s_soc10_video = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_video_train_1.csv')

xperiaxz2compact_15s_soc10 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc10_home_train_1.csv')
xperiaxz2compact_15s_soc20 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc20_home_train_1.csv')
xperiaxz2compact_15s_soc30 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc30_home_train_1.csv')
xperiaxz2compact_15s_soc40 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc40_home_train_1.csv')
xperiaxz2compact_15s_soc50 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc50_home_train_1.csv')
xperiaxz2compact_15s_soc60 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc60_home_train_1.csv')
xperiaxz2compact_15s_soc70 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc70_home_train_1.csv')
xperiaxz2compact_15s_soc80 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc80_home_train_1.csv')
xperiaxz2compact_15s_soc90 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc90_home_train_1.csv')
xperiaxz2compact_15s_soc100 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/XperiaXZ2Compact#1/output_vghub_15s_data_3_xperiaxz2compact#1_soc100_home_train_1.csv')

column_name = 'VBUS Current[A]'
xperiaxz2compact_15s_soc10_home_current_1 = xperiaxz2compact_15s_soc10_home_1[column_name]
xperiaxz2compact_15s_soc10_home_current_2 = xperiaxz2compact_15s_soc10_home_2[column_name]
xperiaxz2compact_15s_soc10_home_current_3 = xperiaxz2compact_15s_soc10_home_3[column_name]
xperiaxz2compact_15s_soc10_home_current_4 = xperiaxz2compact_15s_soc10_home_4[column_name]
xperiaxz2compact_15s_soc10_home_current_5 = xperiaxz2compact_15s_soc10_home_5[column_name]
xperiaxz2compact_15s_soc10_home_current = xperiaxz2compact_15s_soc10_home[column_name]
xperiaxz2compact_15s_soc10_game_current = xperiaxz2compact_15s_soc10_game[column_name]
xperiaxz2compact_15s_soc10_sns_current = xperiaxz2compact_15s_soc10_sns[column_name]
xperiaxz2compact_15s_soc10_video_current = xperiaxz2compact_15s_soc10_video[column_name]
xperiaxz2compact_15s_soc10_current = xperiaxz2compact_15s_soc10[column_name]
xperiaxz2compact_15s_soc20_current = xperiaxz2compact_15s_soc20[column_name]
xperiaxz2compact_15s_soc30_current = xperiaxz2compact_15s_soc30[column_name]
xperiaxz2compact_15s_soc40_current = xperiaxz2compact_15s_soc40[column_name]
xperiaxz2compact_15s_soc50_current = xperiaxz2compact_15s_soc50[column_name]
xperiaxz2compact_15s_soc60_current = xperiaxz2compact_15s_soc60[column_name]
xperiaxz2compact_15s_soc70_current = xperiaxz2compact_15s_soc70[column_name]
xperiaxz2compact_15s_soc80_current = xperiaxz2compact_15s_soc80[column_name]
xperiaxz2compact_15s_soc90_current = xperiaxz2compact_15s_soc90[column_name]
xperiaxz2compact_15s_soc100_current = xperiaxz2compact_15s_soc100[column_name]

column_name = 'VBUS Voltage[V]' 
xperiaxz2compact_15s_soc10_home_voltage_1 = xperiaxz2compact_15s_soc10_home_1[column_name]
xperiaxz2compact_15s_soc10_home_voltage_2 = xperiaxz2compact_15s_soc10_home_2[column_name]
xperiaxz2compact_15s_soc10_home_voltage_3 = xperiaxz2compact_15s_soc10_home_3[column_name]
xperiaxz2compact_15s_soc10_home_voltage_4 = xperiaxz2compact_15s_soc10_home_4[column_name]
xperiaxz2compact_15s_soc10_home_voltage_5 = xperiaxz2compact_15s_soc10_home_5[column_name]
xperiaxz2compact_15s_soc10_home_voltage = xperiaxz2compact_15s_soc10_home[column_name]
xperiaxz2compact_15s_soc10_game_voltage = xperiaxz2compact_15s_soc10_game[column_name]
xperiaxz2compact_15s_soc10_sns_voltage = xperiaxz2compact_15s_soc10_sns[column_name]
xperiaxz2compact_15s_soc10_video_voltage = xperiaxz2compact_15s_soc10_video[column_name]
xperiaxz2compact_15s_soc10_voltage = xperiaxz2compact_15s_soc10[column_name]
xperiaxz2compact_15s_soc20_voltage = xperiaxz2compact_15s_soc20[column_name]
xperiaxz2compact_15s_soc30_voltage = xperiaxz2compact_15s_soc30[column_name]
xperiaxz2compact_15s_soc40_voltage = xperiaxz2compact_15s_soc40[column_name]
xperiaxz2compact_15s_soc50_voltage = xperiaxz2compact_15s_soc50[column_name]
xperiaxz2compact_15s_soc60_voltage = xperiaxz2compact_15s_soc60[column_name]
xperiaxz2compact_15s_soc70_voltage = xperiaxz2compact_15s_soc70[column_name]
xperiaxz2compact_15s_soc80_voltage = xperiaxz2compact_15s_soc80[column_name]
xperiaxz2compact_15s_soc90_voltage = xperiaxz2compact_15s_soc90[column_name]
xperiaxz2compact_15s_soc100_voltage = xperiaxz2compact_15s_soc100[column_name]

column_name = 'VBUS Wattage[W]' 
xperiaxz2compact_15s_soc10_home_wattage_1 = xperiaxz2compact_15s_soc10_home_1[column_name]
xperiaxz2compact_15s_soc10_home_wattage_2 = xperiaxz2compact_15s_soc10_home_2[column_name]
xperiaxz2compact_15s_soc10_home_wattage_3 = xperiaxz2compact_15s_soc10_home_3[column_name]
xperiaxz2compact_15s_soc10_home_wattage_4 = xperiaxz2compact_15s_soc10_home_4[column_name]
xperiaxz2compact_15s_soc10_home_wattage_5 = xperiaxz2compact_15s_soc10_home_5[column_name]
xperiaxz2compact_15s_soc10_home_wattage = xperiaxz2compact_15s_soc10_home[column_name]
xperiaxz2compact_15s_soc10_game_wattage = xperiaxz2compact_15s_soc10_game[column_name]
xperiaxz2compact_15s_soc10_sns_wattage = xperiaxz2compact_15s_soc10_sns[column_name]
xperiaxz2compact_15s_soc10_video_wattage = xperiaxz2compact_15s_soc10_video[column_name]
xperiaxz2compact_15s_soc10_wattage = xperiaxz2compact_15s_soc10[column_name]
xperiaxz2compact_15s_soc20_wattage = xperiaxz2compact_15s_soc20[column_name]
xperiaxz2compact_15s_soc30_wattage = xperiaxz2compact_15s_soc30[column_name]
xperiaxz2compact_15s_soc40_wattage = xperiaxz2compact_15s_soc40[column_name]
xperiaxz2compact_15s_soc50_wattage = xperiaxz2compact_15s_soc50[column_name]
xperiaxz2compact_15s_soc60_wattage = xperiaxz2compact_15s_soc60[column_name]
xperiaxz2compact_15s_soc70_wattage = xperiaxz2compact_15s_soc70[column_name]
xperiaxz2compact_15s_soc80_wattage = xperiaxz2compact_15s_soc80[column_name]
xperiaxz2compact_15s_soc90_wattage = xperiaxz2compact_15s_soc90[column_name]
xperiaxz2compact_15s_soc100_wattage = xperiaxz2compact_15s_soc100[column_name]

# %%
xperiaxz2compact_pdnego_soc10_home_1 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_home_test_1.csv')
xperiaxz2compact_pdnego_soc10_home_2 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_home_test_2.csv')
xperiaxz2compact_pdnego_soc10_home_3 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_home_test_3.csv')
xperiaxz2compact_pdnego_soc10_home_4 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_home_test_4.csv')
xperiaxz2compact_pdnego_soc10_home_5 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_home_test_5.csv')

xperiaxz2compact_pdnego_soc10_home = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_home_test_1.csv')
xperiaxz2compact_pdnego_soc10_game = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_game_test_1.csv')
xperiaxz2compact_pdnego_soc10_sns = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1//output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_sns_test_1.csv')
xperiaxz2compact_pdnego_soc10_video = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_video_test_1.csv')

xperiaxz2compact_pdnego_soc10 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc10_home_test_1.csv')
xperiaxz2compact_pdnego_soc20 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc20_home_test_1.csv')
xperiaxz2compact_pdnego_soc30 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc30_home_test_1.csv')
xperiaxz2compact_pdnego_soc40 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc40_home_test_1.csv')
xperiaxz2compact_pdnego_soc50 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc50_home_test_1.csv')
xperiaxz2compact_pdnego_soc60 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc60_home_test_1.csv')
xperiaxz2compact_pdnego_soc70 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc70_home_test_1.csv')
xperiaxz2compact_pdnego_soc80 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc80_home_test_1.csv')
xperiaxz2compact_pdnego_soc90 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc90_home_test_1.csv')
xperiaxz2compact_pdnego_soc100 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Test/XperiaXZ2Compact#1/output_vghub_pdnego_data_3_xperiaxz2compact#1_soc100_home_test_1.csv')

column_name = 'VBUS Current[A]'
xperiaxz2compact_pdnego_soc10_home_current_1 = xperiaxz2compact_pdnego_soc10_home_1[column_name]
xperiaxz2compact_pdnego_soc10_home_current_2 = xperiaxz2compact_pdnego_soc10_home_2[column_name]
xperiaxz2compact_pdnego_soc10_home_current_3 = xperiaxz2compact_pdnego_soc10_home_3[column_name]
xperiaxz2compact_pdnego_soc10_home_current_4 = xperiaxz2compact_pdnego_soc10_home_4[column_name]
xperiaxz2compact_pdnego_soc10_home_current_5 = xperiaxz2compact_pdnego_soc10_home_5[column_name]
xperiaxz2compact_pdnego_soc10_home_current = xperiaxz2compact_pdnego_soc10_home[column_name]
xperiaxz2compact_pdnego_soc10_game_current = xperiaxz2compact_pdnego_soc10_game[column_name]
xperiaxz2compact_pdnego_soc10_sns_current = xperiaxz2compact_pdnego_soc10_sns[column_name]
xperiaxz2compact_pdnego_soc10_video_current = xperiaxz2compact_pdnego_soc10_video[column_name]
xperiaxz2compact_pdnego_soc10_current = xperiaxz2compact_pdnego_soc10[column_name]
xperiaxz2compact_pdnego_soc20_current = xperiaxz2compact_pdnego_soc20[column_name]
xperiaxz2compact_pdnego_soc30_current = xperiaxz2compact_pdnego_soc30[column_name]
xperiaxz2compact_pdnego_soc40_current = xperiaxz2compact_pdnego_soc40[column_name]
xperiaxz2compact_pdnego_soc50_current = xperiaxz2compact_pdnego_soc50[column_name]
xperiaxz2compact_pdnego_soc60_current = xperiaxz2compact_pdnego_soc60[column_name]
xperiaxz2compact_pdnego_soc70_current = xperiaxz2compact_pdnego_soc70[column_name]
xperiaxz2compact_pdnego_soc80_current = xperiaxz2compact_pdnego_soc80[column_name]
xperiaxz2compact_pdnego_soc90_current = xperiaxz2compact_pdnego_soc90[column_name]
xperiaxz2compact_pdnego_soc100_current = xperiaxz2compact_pdnego_soc100[column_name]

column_name = 'VBUS Voltage[V]'
xperiaxz2compact_pdnego_soc10_home_voltage_1 = xperiaxz2compact_pdnego_soc10_home_1[column_name]
xperiaxz2compact_pdnego_soc10_home_voltage_2 = xperiaxz2compact_pdnego_soc10_home_2[column_name]
xperiaxz2compact_pdnego_soc10_home_voltage_3 = xperiaxz2compact_pdnego_soc10_home_3[column_name]
xperiaxz2compact_pdnego_soc10_home_voltage_4 = xperiaxz2compact_pdnego_soc10_home_4[column_name]
xperiaxz2compact_pdnego_soc10_home_voltage_5 = xperiaxz2compact_pdnego_soc10_home_5[column_name]
xperiaxz2compact_pdnego_soc10_home_voltage = xperiaxz2compact_pdnego_soc10_home[column_name]
xperiaxz2compact_pdnego_soc10_game_voltage = xperiaxz2compact_pdnego_soc10_game[column_name]
xperiaxz2compact_pdnego_soc10_sns_voltage = xperiaxz2compact_pdnego_soc10_sns[column_name]
xperiaxz2compact_pdnego_soc10_video_voltage = xperiaxz2compact_pdnego_soc10_video[column_name]
xperiaxz2compact_pdnego_soc10_voltage = xperiaxz2compact_pdnego_soc10[column_name]
xperiaxz2compact_pdnego_soc20_voltage = xperiaxz2compact_pdnego_soc20[column_name]
xperiaxz2compact_pdnego_soc30_voltage = xperiaxz2compact_pdnego_soc30[column_name]
xperiaxz2compact_pdnego_soc40_voltage = xperiaxz2compact_pdnego_soc40[column_name]
xperiaxz2compact_pdnego_soc50_voltage = xperiaxz2compact_pdnego_soc50[column_name]
xperiaxz2compact_pdnego_soc60_voltage = xperiaxz2compact_pdnego_soc60[column_name]
xperiaxz2compact_pdnego_soc70_voltage = xperiaxz2compact_pdnego_soc70[column_name]
xperiaxz2compact_pdnego_soc80_voltage = xperiaxz2compact_pdnego_soc80[column_name]
xperiaxz2compact_pdnego_soc90_voltage = xperiaxz2compact_pdnego_soc90[column_name]
xperiaxz2compact_pdnego_soc100_voltage = xperiaxz2compact_pdnego_soc100[column_name]

column_name = 'VBUS Wattage[W]' 
xperiaxz2compact_pdnego_soc10_home_wattage_1 = xperiaxz2compact_pdnego_soc10_home_1[column_name]
xperiaxz2compact_pdnego_soc10_home_wattage_2 = xperiaxz2compact_pdnego_soc10_home_2[column_name]
xperiaxz2compact_pdnego_soc10_home_wattage_3 = xperiaxz2compact_pdnego_soc10_home_3[column_name]
xperiaxz2compact_pdnego_soc10_home_wattage_4 = xperiaxz2compact_pdnego_soc10_home_4[column_name]
xperiaxz2compact_pdnego_soc10_home_wattage_5 = xperiaxz2compact_pdnego_soc10_home_5[column_name]
xperiaxz2compact_pdnego_soc10_home_wattage = xperiaxz2compact_pdnego_soc10_home[column_name]
xperiaxz2compact_pdnego_soc10_game_wattage = xperiaxz2compact_pdnego_soc10_game[column_name]
xperiaxz2compact_pdnego_soc10_sns_wattage = xperiaxz2compact_pdnego_soc10_sns[column_name]
xperiaxz2compact_pdnego_soc10_video_wattage = xperiaxz2compact_pdnego_soc10_video[column_name]
xperiaxz2compact_pdnego_soc10_wattage = xperiaxz2compact_pdnego_soc10[column_name]
xperiaxz2compact_pdnego_soc20_wattage = xperiaxz2compact_pdnego_soc20[column_name]
xperiaxz2compact_pdnego_soc30_wattage = xperiaxz2compact_pdnego_soc30[column_name]
xperiaxz2compact_pdnego_soc40_wattage = xperiaxz2compact_pdnego_soc40[column_name]
xperiaxz2compact_pdnego_soc50_wattage = xperiaxz2compact_pdnego_soc50[column_name]
xperiaxz2compact_pdnego_soc60_wattage = xperiaxz2compact_pdnego_soc60[column_name]
xperiaxz2compact_pdnego_soc70_wattage = xperiaxz2compact_pdnego_soc70[column_name]
xperiaxz2compact_pdnego_soc80_wattage = xperiaxz2compact_pdnego_soc80[column_name]
xperiaxz2compact_pdnego_soc90_wattage = xperiaxz2compact_pdnego_soc90[column_name]
xperiaxz2compact_pdnego_soc100_wattage = xperiaxz2compact_pdnego_soc100[column_name]

# %% [markdown]
# ## Comparison method

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(xperiaxz2compact_15s_soc10_home_current_1, label='Xperia XZ2 Compact')
axs[0].plot(xperiaxz2compact_15s_soc10_home_current_2, label='Xperia XZ2 Compact')
axs[0].plot(xperiaxz2compact_15s_soc10_home_current_3, label='Xperia XZ2 Compact')
axs[0].plot(xperiaxz2compact_15s_soc10_home_current_4, label='Xperia XZ2 Compact')
axs[0].plot(xperiaxz2compact_15s_soc10_home_current_5, label='Xperia XZ2 Compact')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(xperiaxz2compact_15s_soc10_home_voltage_1, label='Xperia XZ2 Compact')
axs[1].plot(xperiaxz2compact_15s_soc10_home_voltage_2, label='Xperia XZ2 Compact')
axs[1].plot(xperiaxz2compact_15s_soc10_home_voltage_3, label='Xperia XZ2 Compact')
axs[1].plot(xperiaxz2compact_15s_soc10_home_voltage_4, label='Xperia XZ2 Compact')
axs[1].plot(xperiaxz2compact_15s_soc10_home_voltage_5, label='Xperia XZ2 Compact')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(xperiaxz2compact_15s_soc10_home_wattage_1, label='Xperia XZ2 Compact')
axs[2].plot(xperiaxz2compact_15s_soc10_home_wattage_2, label='Xperia XZ2 Compact')
axs[2].plot(xperiaxz2compact_15s_soc10_home_wattage_3, label='Xperia XZ2 Compact')
axs[2].plot(xperiaxz2compact_15s_soc10_home_wattage_4, label='Xperia XZ2 Compact')
axs[2].plot(xperiaxz2compact_15s_soc10_home_wattage_5, label='Xperia XZ2 Compact')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/XperiaXZ2Compact#1/15s/vghub_15s_xperiaxz2compact#1_soc10_home_CVW.png')
plt.show()

# %% [markdown]
# ## Proposed method

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(xperiaxz2compact_pdnego_soc10_home_current_1, label='Xperia XZ2 Compact')
axs[0].plot(xperiaxz2compact_pdnego_soc10_home_current_2, label='Xperia XZ2 Compact')
axs[0].plot(xperiaxz2compact_pdnego_soc10_home_current_3, label='Xperia XZ2 Compact')
axs[0].plot(xperiaxz2compact_pdnego_soc10_home_current_4, label='Xperia XZ2 Compact')
axs[0].plot(xperiaxz2compact_pdnego_soc10_home_current_5, label='Xperia XZ2 Compact')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(xperiaxz2compact_pdnego_soc10_home_voltage_1, label='Xperia XZ2 Compact')
axs[1].plot(xperiaxz2compact_pdnego_soc10_home_voltage_2, label='Xperia XZ2 Compact')
axs[1].plot(xperiaxz2compact_pdnego_soc10_home_voltage_3, label='Xperia XZ2 Compact')
axs[1].plot(xperiaxz2compact_pdnego_soc10_home_voltage_4, label='Xperia XZ2 Compact')
axs[1].plot(xperiaxz2compact_15s_soc10_home_voltage_5, label='Xperia XZ2 Compact')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(xperiaxz2compact_pdnego_soc10_home_wattage_1, label='Xperia XZ2 Compact')
axs[2].plot(xperiaxz2compact_pdnego_soc10_home_wattage_2, label='Xperia XZ2 Compact')
axs[2].plot(xperiaxz2compact_pdnego_soc10_home_wattage_3, label='Xperia XZ2 Compact')
axs[2].plot(xperiaxz2compact_pdnego_soc10_home_wattage_4, label='Xperia XZ2 Compact')
axs[2].plot(xperiaxz2compact_pdnego_soc10_home_wattage_5, label='Xperia XZ2 Compact')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/XperiaXZ2Compact#1/PDNego/vghub_pdnego_xperiaxz2compact#1_soc10_home_CVW.png')
plt.show()

# %% [markdown]
# ## Comparison method: Application startup state comparison

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(xperiaxz2compact_15s_soc10_game_current, label='Game')
axs[0].plot(xperiaxz2compact_15s_soc10_home_current, label='Home')
axs[0].plot(xperiaxz2compact_15s_soc10_sns_current, label='SNS')
axs[0].plot(xperiaxz2compact_15s_soc10_video_current, label='Video')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(xperiaxz2compact_15s_soc10_game_voltage, label='Game')
axs[1].plot(xperiaxz2compact_15s_soc10_home_voltage, label='Home')
axs[1].plot(xperiaxz2compact_15s_soc10_sns_voltage, label='SNS')
axs[1].plot(xperiaxz2compact_15s_soc10_video_voltage, label='Video')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(xperiaxz2compact_15s_soc10_game_wattage, label='Game')
axs[2].plot(xperiaxz2compact_15s_soc10_home_wattage, label='Home')
axs[2].plot(xperiaxz2compact_15s_soc10_sns_wattage, label='SNS')
axs[2].plot(xperiaxz2compact_15s_soc10_video_wattage, label='Video')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/XperiaXZ2Compact#1/15s/vghub_15s_xperiaxz2compact#1_soc10_app_CVW.png')
plt.show()

# %% [markdown]
# ## Proposed method: Application startup state comparison

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(xperiaxz2compact_pdnego_soc10_game_current, label='Game')
axs[0].plot(xperiaxz2compact_pdnego_soc10_home_current, label='Home')
axs[0].plot(xperiaxz2compact_pdnego_soc10_sns_current, label='SNS')
axs[0].plot(xperiaxz2compact_pdnego_soc10_video_current, label='Video')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(xperiaxz2compact_pdnego_soc10_game_voltage, label='Game')
axs[1].plot(xperiaxz2compact_pdnego_soc10_home_voltage, label='Home')
axs[1].plot(xperiaxz2compact_pdnego_soc10_sns_voltage, label='SNS')
axs[1].plot(xperiaxz2compact_pdnego_soc10_video_voltage, label='Video')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(xperiaxz2compact_pdnego_soc10_game_wattage, label='Game')
axs[2].plot(xperiaxz2compact_pdnego_soc10_home_wattage, label='Home')
axs[2].plot(xperiaxz2compact_pdnego_soc10_sns_wattage, label='SNS')
axs[2].plot(xperiaxz2compact_pdnego_soc10_video_wattage, label='Video')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/XperiaXZ2Compact#1/PDNego/vghub_pdnego_xperiaxz2compact#1_soc10_app_CVW.png')
plt.show()

# %% [markdown]
# ## Comparison method: SOC (State Of Charge) comparison

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(xperiaxz2compact_15s_soc10_current, label='SOC 10%')
axs[0].plot(xperiaxz2compact_15s_soc20_current, label='SOC 20%')
axs[0].plot(xperiaxz2compact_15s_soc30_current, label='SOC 30%')
axs[0].plot(xperiaxz2compact_15s_soc40_current, label='SOC 40%')
axs[0].plot(xperiaxz2compact_15s_soc50_current, label='SOC 50%')
axs[0].plot(xperiaxz2compact_15s_soc60_current, label='SOC 60%')
axs[0].plot(xperiaxz2compact_15s_soc70_current, label='SOC 70%')
axs[0].plot(xperiaxz2compact_15s_soc80_current, label='SOC 80%')
axs[0].plot(xperiaxz2compact_15s_soc90_current, label='SOC 90%')
axs[0].plot(xperiaxz2compact_15s_soc100_current, label='SOC 100%')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(xperiaxz2compact_15s_soc10_voltage, label='SOC 10%')
axs[1].plot(xperiaxz2compact_15s_soc20_voltage, label='SOC 20%')
axs[1].plot(xperiaxz2compact_15s_soc30_voltage, label='SOC 30%')
axs[1].plot(xperiaxz2compact_15s_soc40_voltage, label='SOC 40%')
axs[1].plot(xperiaxz2compact_15s_soc50_voltage, label='SOC 50%')
axs[1].plot(xperiaxz2compact_15s_soc60_voltage, label='SOC 60%')
axs[1].plot(xperiaxz2compact_15s_soc70_voltage, label='SOC 70%')
axs[1].plot(xperiaxz2compact_15s_soc80_voltage, label='SOC 80%')
axs[1].plot(xperiaxz2compact_15s_soc90_voltage, label='SOC 90%')
axs[1].plot(xperiaxz2compact_15s_soc100_voltage, label='SOC 100%')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(xperiaxz2compact_15s_soc10_wattage, label='SOC 10%')
axs[2].plot(xperiaxz2compact_15s_soc20_wattage, label='SOC 20%')
axs[2].plot(xperiaxz2compact_15s_soc30_wattage, label='SOC 30%')
axs[2].plot(xperiaxz2compact_15s_soc40_wattage, label='SOC 40%')
axs[2].plot(xperiaxz2compact_15s_soc50_wattage, label='SOC 50%')
axs[2].plot(xperiaxz2compact_15s_soc60_wattage, label='SOC 60%')
axs[2].plot(xperiaxz2compact_15s_soc70_wattage, label='SOC 70%')
axs[2].plot(xperiaxz2compact_15s_soc80_wattage, label='SOC 80%')
axs[2].plot(xperiaxz2compact_15s_soc90_wattage, label='SOC 90%')
axs[2].plot(xperiaxz2compact_15s_soc100_wattage, label='SOC 100%')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/XperiaXZ2Compact#1/15s/vghub_15s_xperiaxz2compact#1_soc_home_CVW.png')
plt.show()

# %% [markdown]
# ## Proposed method: SOC (State Of Charge) comparison

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(xperiaxz2compact_pdnego_soc10_current, label='SOC 10%')
axs[0].plot(xperiaxz2compact_pdnego_soc20_current, label='SOC 20%')
axs[0].plot(xperiaxz2compact_pdnego_soc30_current, label='SOC 30%')
axs[0].plot(xperiaxz2compact_pdnego_soc40_current, label='SOC 40%')
axs[0].plot(xperiaxz2compact_pdnego_soc50_current, label='SOC 50%')
axs[0].plot(xperiaxz2compact_pdnego_soc60_current, label='SOC 60%')
axs[0].plot(xperiaxz2compact_pdnego_soc70_current, label='SOC 70%')
axs[0].plot(xperiaxz2compact_pdnego_soc80_current, label='SOC 80%')
axs[0].plot(xperiaxz2compact_pdnego_soc90_current, label='SOC 90%')
axs[0].plot(xperiaxz2compact_pdnego_soc100_current, label='SOC 100%')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(xperiaxz2compact_pdnego_soc10_voltage, label='SOC 10%')
axs[1].plot(xperiaxz2compact_pdnego_soc20_voltage, label='SOC 20%')
axs[1].plot(xperiaxz2compact_pdnego_soc30_voltage, label='SOC 30%')
axs[1].plot(xperiaxz2compact_pdnego_soc40_voltage, label='SOC 40%')
axs[1].plot(xperiaxz2compact_pdnego_soc50_voltage, label='SOC 50%')
axs[1].plot(xperiaxz2compact_pdnego_soc60_voltage, label='SOC 60%')
axs[1].plot(xperiaxz2compact_pdnego_soc70_voltage, label='SOC 70%')
axs[1].plot(xperiaxz2compact_pdnego_soc80_voltage, label='SOC 80%')
axs[1].plot(xperiaxz2compact_pdnego_soc90_voltage, label='SOC 90%')
axs[1].plot(xperiaxz2compact_pdnego_soc100_voltage, label='SOC 100%')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(xperiaxz2compact_pdnego_soc10_wattage, label='SOC 10%')
axs[2].plot(xperiaxz2compact_pdnego_soc20_wattage, label='SOC 20%')
axs[2].plot(xperiaxz2compact_pdnego_soc30_wattage, label='SOC 30%')
axs[2].plot(xperiaxz2compact_pdnego_soc40_wattage, label='SOC 40%')
axs[2].plot(xperiaxz2compact_pdnego_soc50_wattage, label='SOC 50%')
axs[2].plot(xperiaxz2compact_pdnego_soc60_wattage, label='SOC 60%')
axs[2].plot(xperiaxz2compact_pdnego_soc70_wattage, label='SOC 70%')
axs[2].plot(xperiaxz2compact_pdnego_soc80_wattage, label='SOC 80%')
axs[2].plot(xperiaxz2compact_pdnego_soc90_wattage, label='SOC 90%')
axs[2].plot(xperiaxz2compact_pdnego_soc100_wattage, label='SOC 100%')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/XperiaXZ2Compact#1/PDNego/vghub_pdnego_xperiaxz2compact#1_soc_home_CVW.png')
plt.show()
