# %% [markdown]
# # Anker Power Core III #1 Visualization

# %% [markdown]
# ## Premise
# *Comparison method*：Measure for 15 seconds.
# *Proposed method*：Measure for 15 seconds and **filter during USB PD negotiation period.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ankerpowercore3_15s_soc25_home_1 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc25_home_train_1.csv')
ankerpowercore3_15s_soc25_home_2 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc25_home_train_2.csv')
ankerpowercore3_15s_soc25_home_3 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc25_home_train_3.csv')
ankerpowercore3_15s_soc25_home_4 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc25_home_train_4.csv')
ankerpowercore3_15s_soc25_home_5 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc25_home_train_5.csv')

ankerpowercore3_15s_soc25 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc25_home_train_1.csv')
ankerpowercore3_15s_soc50 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc50_home_train_1.csv')
ankerpowercore3_15s_soc75 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc75_home_train_1.csv')
ankerpowercore3_15s_soc100 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc100_home_train_1.csv')

column_name = 'VBUS Current[A]'
ankerpowercore3_15s_soc25_home_current_1 = ankerpowercore3_15s_soc25_home_1[column_name]
ankerpowercore3_15s_soc25_home_current_2 = ankerpowercore3_15s_soc25_home_2[column_name]
ankerpowercore3_15s_soc25_home_current_3 = ankerpowercore3_15s_soc25_home_3[column_name]
ankerpowercore3_15s_soc25_home_current_4 = ankerpowercore3_15s_soc25_home_4[column_name]
ankerpowercore3_15s_soc25_home_current_5 = ankerpowercore3_15s_soc25_home_5[column_name]
ankerpowercore3_15s_soc25_current = ankerpowercore3_15s_soc25[column_name]
ankerpowercore3_15s_soc50_current = ankerpowercore3_15s_soc50[column_name]
ankerpowercore3_15s_soc75_current = ankerpowercore3_15s_soc75[column_name]
ankerpowercore3_15s_soc100_current = ankerpowercore3_15s_soc100[column_name]

column_name = 'VBUS Voltage[V]' 
ankerpowercore3_15s_soc25_home_voltage_1 = ankerpowercore3_15s_soc25_home_1[column_name]
ankerpowercore3_15s_soc25_home_voltage_2 = ankerpowercore3_15s_soc25_home_2[column_name]
ankerpowercore3_15s_soc25_home_voltage_3 = ankerpowercore3_15s_soc25_home_3[column_name]
ankerpowercore3_15s_soc25_home_voltage_4 = ankerpowercore3_15s_soc25_home_4[column_name]
ankerpowercore3_15s_soc25_home_voltage_5 = ankerpowercore3_15s_soc25_home_5[column_name]
ankerpowercore3_15s_soc25_voltage = ankerpowercore3_15s_soc25[column_name]
ankerpowercore3_15s_soc50_voltage = ankerpowercore3_15s_soc50[column_name]
ankerpowercore3_15s_soc75_voltage = ankerpowercore3_15s_soc75[column_name]
ankerpowercore3_15s_soc100_voltage = ankerpowercore3_15s_soc100[column_name]

column_name = 'VBUS Wattage[W]' 
ankerpowercore3_15s_soc25_home_wattage_1 = ankerpowercore3_15s_soc25_home_1[column_name]
ankerpowercore3_15s_soc25_home_wattage_2 = ankerpowercore3_15s_soc25_home_2[column_name]
ankerpowercore3_15s_soc25_home_wattage_3 = ankerpowercore3_15s_soc25_home_3[column_name]
ankerpowercore3_15s_soc25_home_wattage_4 = ankerpowercore3_15s_soc25_home_4[column_name]
ankerpowercore3_15s_soc25_home_wattage_5 = ankerpowercore3_15s_soc25_home_5[column_name]
ankerpowercore3_15s_soc25_wattage = ankerpowercore3_15s_soc25[column_name]
ankerpowercore3_15s_soc50_wattage = ankerpowercore3_15s_soc50[column_name]
ankerpowercore3_15s_soc75_wattage = ankerpowercore3_15s_soc75[column_name]
ankerpowercore3_15s_soc100_wattage = ankerpowercore3_15s_soc100[column_name]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 9
#       7 ankerpowercore3_15s_soc25 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc25_home_train_1.csv')
#       8 ankerpowercore3_15s_soc50 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc50_home_train_1.csv')
# ----> 9 ankerpowercore3_15s_soc75 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc75_home_train_1.csv')
#      10 ankerpowercore3_15s_soc100 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/AnkerPowerCore3#1/output_vghub_15s_data_3_ankerpowercore3#1_soc100_home_train_1.csv')
# ...

# %%
ankerpowercore3_pdnego_soc25_home_1 = pd.read_csv('../VirtualGridHub/VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/AnkerPowerCore3#1/output_vghub_pdnego_data_3_ankerpowercore3#1_soc25_home_train_1.csv')
ankerpowercore3_pdnego_soc25_home_2 = pd.read_csv('../VirtualGridHub/VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/AnkerPowerCore3#1/output_vghub_pdnego_data_3_ankerpowercore3#1_soc25_home_train_2.csv')
ankerpowercore3_pdnego_soc25_home_3 = pd.read_csv('../VirtualGridHub/VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/AnkerPowerCore3#1/output_vghub_pdnego_data_3_ankerpowercore3#1_soc25_home_train_3.csv')
ankerpowercore3_pdnego_soc25_home_4 = pd.read_csv('../VirtualGridHub/VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/AnkerPowerCore3#1/output_vghub_pdnego_data_3_ankerpowercore3#1_soc25_home_train_4.csv')
ankerpowercore3_pdnego_soc25_home_5 = pd.read_csv('../VirtualGridHub/VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/AnkerPowerCore3#1/output_vghub_pdnego_data_3_ankerpowercore3#1_soc25_home_train_5.csv')

ankerpowercore3_pdnego_soc25 = pd.read_csv('../VirtualGridHub/VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/AnkerPowerCore3#1/output_vghub_pdnego_data_3_ankerpowercore3#1_soc25_home_train_1.csv')
ankerpowercore3_pdnego_soc50 = pd.read_csv('../VirtualGridHub/VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/AnkerPowerCore3#1/output_vghub_pdnego_data_3_ankerpowercore3#1_soc50_home_train_1.csv')
ankerpowercore3_pdnego_soc75 = pd.read_csv('../VirtualGridHub/VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/AnkerPowerCore3#1/output_vghub_pdnego_data_3_ankerpowercore3#1_soc75_home_train_1.csv')
ankerpowercore3_pdnego_soc100 = pd.read_csv('../VirtualGridHub/VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/AnkerPowerCore3#1/output_vghub_pdnego_data_3_ankerpowercore3#1_soc100_home_train_1.csv')

column_name = 'VBUS Current[A]'
ankerpowercore3_pdnego_soc25_home_current_1 = ankerpowercore3_pdnego_soc25_home_1[column_name]
ankerpowercore3_pdnego_soc25_home_current_2 = ankerpowercore3_pdnego_soc25_home_2[column_name]
ankerpowercore3_pdnego_soc25_home_current_3 = ankerpowercore3_pdnego_soc25_home_3[column_name]
ankerpowercore3_pdnego_soc25_home_current_4 = ankerpowercore3_pdnego_soc25_home_4[column_name]
ankerpowercore3_pdnego_soc25_home_current_5 = ankerpowercore3_pdnego_soc25_home_5[column_name]
ankerpowercore3_pdnego_soc25_current = ankerpowercore3_pdnego_soc25[column_name]
ankerpowercore3_pdnego_soc50_current = ankerpowercore3_pdnego_soc50[column_name]
ankerpowercore3_pdnego_soc75_current = ankerpowercore3_pdnego_soc75[column_name]
ankerpowercore3_pdnego_soc100_current = ankerpowercore3_pdnego_soc100[column_name]

column_name = 'VBUS Voltage[V]'
ankerpowercore3_pdnego_soc25_home_voltage_1 = ankerpowercore3_pdnego_soc25_home_1[column_name]
ankerpowercore3_pdnego_soc25_home_voltage_2 = ankerpowercore3_pdnego_soc25_home_2[column_name]
ankerpowercore3_pdnego_soc25_home_voltage_3 = ankerpowercore3_pdnego_soc25_home_3[column_name]
ankerpowercore3_pdnego_soc25_home_voltage_4 = ankerpowercore3_pdnego_soc25_home_4[column_name]
ankerpowercore3_pdnego_soc25_home_voltage_5 = ankerpowercore3_pdnego_soc25_home_5[column_name]
ankerpowercore3_pdnego_soc25_voltage = ankerpowercore3_pdnego_soc25[column_name]
ankerpowercore3_pdnego_soc50_voltage = ankerpowercore3_pdnego_soc50[column_name]
ankerpowercore3_pdnego_soc75_voltage = ankerpowercore3_pdnego_soc75[column_name]
ankerpowercore3_pdnego_soc100_voltage = ankerpowercore3_pdnego_soc100[column_name]

column_name = 'VBUS Wattage[W]' 
ankerpowercore3_pdnego_soc25_home_wattage_1 = ankerpowercore3_pdnego_soc25_home_1[column_name]
ankerpowercore3_pdnego_soc25_home_wattage_2 = ankerpowercore3_pdnego_soc25_home_2[column_name]
ankerpowercore3_pdnego_soc25_home_wattage_3 = ankerpowercore3_pdnego_soc25_home_3[column_name]
ankerpowercore3_pdnego_soc25_home_wattage_4 = ankerpowercore3_pdnego_soc25_home_4[column_name]
ankerpowercore3_pdnego_soc25_home_wattage_5 = ankerpowercore3_pdnego_soc25_home_5[column_name]
ankerpowercore3_pdnego_soc25_wattage = ankerpowercore3_pdnego_soc25[column_name]
ankerpowercore3_pdnego_soc50_wattage = ankerpowercore3_pdnego_soc50[column_name]
ankerpowercore3_pdnego_soc75_wattage = ankerpowercore3_pdnego_soc75[column_name]
ankerpowercore3_pdnego_soc100_wattage = ankerpowercore3_pdnego_soc100[column_name]

# %% [markdown]
# ## Comparison method

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(ankerpowercore3_15s_soc25_home_current_1, label='Anker Power Core 3')
axs[0].plot(ankerpowercore3_15s_soc25_home_current_2, label='Anker Power Core 3')
axs[0].plot(ankerpowercore3_15s_soc25_home_current_3, label='Anker Power Core 3')
axs[0].plot(ankerpowercore3_15s_soc25_home_current_4, label='Anker Power Core 3')
axs[0].plot(ankerpowercore3_15s_soc25_home_current_5, label='Anker Power Core 3')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(ankerpowercore3_15s_soc25_home_voltage_1, label='Anker Power Core 3')
axs[1].plot(ankerpowercore3_15s_soc25_home_voltage_2, label='Anker Power Core 3')
axs[1].plot(ankerpowercore3_15s_soc25_home_voltage_3, label='Anker Power Core 3')
axs[1].plot(ankerpowercore3_15s_soc25_home_voltage_4, label='Anker Power Core 3')
axs[1].plot(ankerpowercore3_15s_soc25_home_voltage_5, label='Anker Power Core 3')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(ankerpowercore3_15s_soc25_home_wattage_1, label='Anker Power Core 3')
axs[2].plot(ankerpowercore3_15s_soc25_home_wattage_2, label='Anker Power Core 3')
axs[2].plot(ankerpowercore3_15s_soc25_home_wattage_3, label='Anker Power Core 3')
axs[2].plot(ankerpowercore3_15s_soc25_home_wattage_4, label='Anker Power Core 3')
axs[2].plot(ankerpowercore3_15s_soc25_home_wattage_5, label='Anker Power Core 3')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/AnkerPowerCore3#1/15s/vghub_15s_ankerpowercore3#1_soc10_home_CVW.png')
plt.show()

# %% [markdown]
# ## Proposed method

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(ankerpowercore3_pdnego_soc25_home_current_1, label='Anker Power Core 3')
axs[0].plot(ankerpowercore3_pdnego_soc25_home_current_2, label='Anker Power Core 3')
axs[0].plot(ankerpowercore3_pdnego_soc25_home_current_3, label='Anker Power Core 3')
axs[0].plot(ankerpowercore3_pdnego_soc25_home_current_4, label='Anker Power Core 3')
axs[0].plot(ankerpowercore3_pdnego_soc25_home_current_5, label='Anker Power Core 3')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(ankerpowercore3_pdnego_soc25_home_voltage_1, label='Anker Power Core 3')
axs[1].plot(ankerpowercore3_pdnego_soc25_home_voltage_2, label='Anker Power Core 3')
axs[1].plot(ankerpowercore3_pdnego_soc25_home_voltage_3, label='Anker Power Core 3')
axs[1].plot(ankerpowercore3_pdnego_soc25_home_voltage_4, label='Anker Power Core 3')
axs[1].plot(ankerpowercore3_pdnego_soc25_home_voltage_5, label='Anker Power Core 3')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(ankerpowercore3_pdnego_soc25_home_wattage_1, label='Anker Power Core 3')
axs[2].plot(ankerpowercore3_pdnego_soc25_home_wattage_2, label='Anker Power Core 3')
axs[2].plot(ankerpowercore3_pdnego_soc25_home_wattage_3, label='Anker Power Core 3')
axs[2].plot(ankerpowercore3_pdnego_soc25_home_wattage_4, label='Anker Power Core 3')
axs[2].plot(ankerpowercore3_pdnego_soc25_home_wattage_5, label='Anker Power Core 3')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/AnkerPowerCore3#1/PDNego/vghub_pdnego_ankerpowercore3#1_soc10_home_CVW.png')
plt.show()

# %% [markdown]
# ## Comparison method: SOC (State Of Charge) comparison

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(ankerpowercore3_15s_soc25_current, label='SOC 25%')
axs[0].plot(ankerpowercore3_15s_soc50_current, label='SOC 50%')
axs[0].plot(ankerpowercore3_15s_soc75_current, label='SOC 75%')
axs[0].plot(ankerpowercore3_15s_soc100_current, label='SOC 100%')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(ankerpowercore3_15s_soc25_voltage, label='SOC 25%')
axs[1].plot(ankerpowercore3_15s_soc50_voltage, label='SOC 50%')
axs[1].plot(ankerpowercore3_15s_soc75_voltage, label='SOC 75%')
axs[1].plot(ankerpowercore3_15s_soc100_voltage, label='SOC 100%')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(ankerpowercore3_15s_soc25_wattage, label='SOC 25%')
axs[2].plot(ankerpowercore3_15s_soc50_wattage, label='SOC 50%')
axs[2].plot(ankerpowercore3_15s_soc75_wattage, label='SOC 75%')
axs[2].plot(ankerpowercore3_15s_soc100_wattage, label='SOC 100%')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/AnkerPowerCore3#1/15s/vghub_15s_ankerpowercore3#1_soc_home_CVW.png')
plt.show()

# %% [markdown]
# ## Proposed method: SOC (State Of Charge) comparison

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(ankerpowercore3_pdnego_soc25_current, label='SOC 25%')
axs[0].plot(ankerpowercore3_pdnego_soc50_current, label='SOC 50%')
axs[0].plot(ankerpowercore3_pdnego_soc75_current, label='SOC 75%')
axs[0].plot(ankerpowercore3_pdnego_soc100_current, label='SOC 100%')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(ankerpowercore3_pdnego_soc25_voltage, label='SOC 25%')
axs[1].plot(ankerpowercore3_pdnego_soc50_voltage, label='SOC 50%')
axs[1].plot(ankerpowercore3_pdnego_soc75_voltage, label='SOC 75%')
axs[1].plot(ankerpowercore3_pdnego_soc100_voltage, label='SOC 100%')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(ankerpowercore3_pdnego_soc25_wattage, label='SOC 25%')
axs[2].plot(ankerpowercore3_pdnego_soc50_wattage, label='SOC 50%')
axs[2].plot(ankerpowercore3_pdnego_soc75_wattage, label='SOC 75%')
axs[2].plot(ankerpowercore3_pdnego_soc100_wattage, label='SOC 100%')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/AnkerPowerCore3#1/PDNego/vghub_pdnego_ankerpowercore3#1_soc_home_CVW.png')
plt.show()
