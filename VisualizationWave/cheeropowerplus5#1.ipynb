# %% [markdown]
# # cheero Power Plus 5 #1 Visualization

# %% [markdown]
# ## Premise
# *Comparison method*：Measure for 15 seconds.
# *Proposed method*：Measure for 15 seconds and **filter during USB PD negotiation period.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cheeropowerplus5_15s_soc10_home_1 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc10_train_1.csv')
cheeropowerplus5_15s_soc10_home_2 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc10_train_2.csv')
cheeropowerplus5_15s_soc10_home_3 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc10_train_3.csv')
cheeropowerplus5_15s_soc10_home_4 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc10_train_4.csv')
cheeropowerplus5_15s_soc10_home_5 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc10_train_5.csv')

cheeropowerplus5_15s_soc10 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc10_train_1.csv')
cheeropowerplus5_15s_soc20 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc20_train_1.csv')
cheeropowerplus5_15s_soc30 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc30_train_1.csv')
cheeropowerplus5_15s_soc40 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc40_train_1.csv')
cheeropowerplus5_15s_soc50 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc50_home_train_1.csv')
cheeropowerplus5_15s_soc60 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc60_home_train_1.csv')
cheeropowerplus5_15s_soc70 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc70_home_train_1.csv')
cheeropowerplus5_15s_soc80 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc80_home_train_1.csv')
cheeropowerplus5_15s_soc90 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc90_home_train_1.csv')
cheeropowerplus5_15s_soc100 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/Dataset15s/Train/cheeroPowerPlus5#1/output_vghub_15s_data_3_cheeropowerplus5#1_soc100_home_train_1.csv')

column_name = 'VBUS Current[A]'
cheeropowerplus5_15s_soc10_home_current_1 = cheeropowerplus5_15s_soc10_home_1[column_name]
cheeropowerplus5_15s_soc10_home_current_2 = cheeropowerplus5_15s_soc10_home_2[column_name]
cheeropowerplus5_15s_soc10_home_current_3 = cheeropowerplus5_15s_soc10_home_3[column_name]
cheeropowerplus5_15s_soc10_home_current_4 = cheeropowerplus5_15s_soc10_home_4[column_name]
cheeropowerplus5_15s_soc10_home_current_5 = cheeropowerplus5_15s_soc10_home_5[column_name]
cheeropowerplus5_15s_soc10_current = cheeropowerplus5_15s_soc10[column_name]
cheeropowerplus5_15s_soc20_current = cheeropowerplus5_15s_soc20[column_name]
cheeropowerplus5_15s_soc30_current = cheeropowerplus5_15s_soc30[column_name]
cheeropowerplus5_15s_soc40_current = cheeropowerplus5_15s_soc40[column_name]
cheeropowerplus5_15s_soc50_current = cheeropowerplus5_15s_soc50[column_name]
cheeropowerplus5_15s_soc60_current = cheeropowerplus5_15s_soc60[column_name]
cheeropowerplus5_15s_soc70_current = cheeropowerplus5_15s_soc70[column_name]
cheeropowerplus5_15s_soc80_current = cheeropowerplus5_15s_soc80[column_name]
cheeropowerplus5_15s_soc90_current = cheeropowerplus5_15s_soc90[column_name]
cheeropowerplus5_15s_soc100_current = cheeropowerplus5_15s_soc100[column_name]

column_name = 'VBUS Voltage[V]' 
cheeropowerplus5_15s_soc10_home_voltage_1 = cheeropowerplus5_15s_soc10_home_1[column_name]
cheeropowerplus5_15s_soc10_home_voltage_2 = cheeropowerplus5_15s_soc10_home_2[column_name]
cheeropowerplus5_15s_soc10_home_voltage_3 = cheeropowerplus5_15s_soc10_home_3[column_name]
cheeropowerplus5_15s_soc10_home_voltage_4 = cheeropowerplus5_15s_soc10_home_4[column_name]
cheeropowerplus5_15s_soc10_home_voltage_5 = cheeropowerplus5_15s_soc10_home_5[column_name]
cheeropowerplus5_15s_soc10_voltage = cheeropowerplus5_15s_soc10[column_name]
cheeropowerplus5_15s_soc20_voltage = cheeropowerplus5_15s_soc20[column_name]
cheeropowerplus5_15s_soc30_voltage = cheeropowerplus5_15s_soc30[column_name]
cheeropowerplus5_15s_soc40_voltage = cheeropowerplus5_15s_soc40[column_name]
cheeropowerplus5_15s_soc50_voltage = cheeropowerplus5_15s_soc50[column_name]
cheeropowerplus5_15s_soc60_voltage = cheeropowerplus5_15s_soc60[column_name]
cheeropowerplus5_15s_soc70_voltage = cheeropowerplus5_15s_soc70[column_name]
cheeropowerplus5_15s_soc80_voltage = cheeropowerplus5_15s_soc80[column_name]
cheeropowerplus5_15s_soc90_voltage = cheeropowerplus5_15s_soc90[column_name]
cheeropowerplus5_15s_soc100_voltage = cheeropowerplus5_15s_soc100[column_name]

column_name = 'VBUS Wattage[W]' 
cheeropowerplus5_15s_soc10_home_wattage_1 = cheeropowerplus5_15s_soc10_home_1[column_name]
cheeropowerplus5_15s_soc10_home_wattage_2 = cheeropowerplus5_15s_soc10_home_2[column_name]
cheeropowerplus5_15s_soc10_home_wattage_3 = cheeropowerplus5_15s_soc10_home_3[column_name]
cheeropowerplus5_15s_soc10_home_wattage_4 = cheeropowerplus5_15s_soc10_home_4[column_name]
cheeropowerplus5_15s_soc10_home_wattage_5 = cheeropowerplus5_15s_soc10_home_5[column_name]
cheeropowerplus5_15s_soc10_wattage = cheeropowerplus5_15s_soc10[column_name]
cheeropowerplus5_15s_soc20_wattage = cheeropowerplus5_15s_soc20[column_name]
cheeropowerplus5_15s_soc30_wattage = cheeropowerplus5_15s_soc30[column_name]
cheeropowerplus5_15s_soc40_wattage = cheeropowerplus5_15s_soc40[column_name]
cheeropowerplus5_15s_soc50_wattage = cheeropowerplus5_15s_soc50[column_name]
cheeropowerplus5_15s_soc60_wattage = cheeropowerplus5_15s_soc60[column_name]
cheeropowerplus5_15s_soc70_wattage = cheeropowerplus5_15s_soc70[column_name]
cheeropowerplus5_15s_soc80_wattage = cheeropowerplus5_15s_soc80[column_name]
cheeropowerplus5_15s_soc90_wattage = cheeropowerplus5_15s_soc90[column_name]
cheeropowerplus5_15s_soc100_wattage = cheeropowerplus5_15s_soc100[column_name]

# %%
cheeropowerplus5_pdnego_soc10_home_1 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc10_train_1.csv')
cheeropowerplus5_pdnego_soc10_home_2 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc10_train_2.csv')
cheeropowerplus5_pdnego_soc10_home_3 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc10_train_3.csv')
cheeropowerplus5_pdnego_soc10_home_4 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc10_train_4.csv')
cheeropowerplus5_pdnego_soc10_home_5 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc10_train_5.csv')

cheeropowerplus5_pdnego_soc10 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc10_train_1.csv')
cheeropowerplus5_pdnego_soc20 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc20_train_1.csv')
cheeropowerplus5_pdnego_soc30 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc30_train_1.csv')
cheeropowerplus5_pdnego_soc40 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc40_train_1.csv')
cheeropowerplus5_pdnego_soc50 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc50_home_train_1.csv')
cheeropowerplus5_pdnego_soc60 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc60_home_train_1.csv')
cheeropowerplus5_pdnego_soc70 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc70_home_train_1.csv')
cheeropowerplus5_pdnego_soc80 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc80_home_train_1.csv')
cheeropowerplus5_pdnego_soc90 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc90_home_train_1.csv')
cheeropowerplus5_pdnego_soc100 = pd.read_csv('../VirtualGridHub/DevicesClassify/EvalCSV/DatasetPDNego/Train/cheeroPowerPlus5#1/output_vghub_pdnego_data_3_cheeropowerplus5#1_soc100_home_train_1.csv')

column_name = 'VBUS Current[A]'
cheeropowerplus5_pdnego_soc10_home_current_1 = cheeropowerplus5_pdnego_soc10_home_1[column_name]
cheeropowerplus5_pdnego_soc10_home_current_2 = cheeropowerplus5_pdnego_soc10_home_2[column_name]
cheeropowerplus5_pdnego_soc10_home_current_3 = cheeropowerplus5_pdnego_soc10_home_3[column_name]
cheeropowerplus5_pdnego_soc10_home_current_4 = cheeropowerplus5_pdnego_soc10_home_4[column_name]
cheeropowerplus5_pdnego_soc10_home_current_5 = cheeropowerplus5_pdnego_soc10_home_5[column_name]
cheeropowerplus5_pdnego_soc10_current = cheeropowerplus5_pdnego_soc10[column_name]
cheeropowerplus5_pdnego_soc20_current = cheeropowerplus5_pdnego_soc20[column_name]
cheeropowerplus5_pdnego_soc30_current = cheeropowerplus5_pdnego_soc30[column_name]
cheeropowerplus5_pdnego_soc40_current = cheeropowerplus5_pdnego_soc40[column_name]
cheeropowerplus5_pdnego_soc50_current = cheeropowerplus5_pdnego_soc50[column_name]
cheeropowerplus5_pdnego_soc60_current = cheeropowerplus5_pdnego_soc60[column_name]
cheeropowerplus5_pdnego_soc70_current = cheeropowerplus5_pdnego_soc70[column_name]
cheeropowerplus5_pdnego_soc80_current = cheeropowerplus5_pdnego_soc80[column_name]
cheeropowerplus5_pdnego_soc90_current = cheeropowerplus5_pdnego_soc90[column_name]
cheeropowerplus5_pdnego_soc100_current = cheeropowerplus5_pdnego_soc100[column_name]

column_name = 'VBUS Voltage[V]'
cheeropowerplus5_pdnego_soc10_home_voltage_1 = cheeropowerplus5_pdnego_soc10_home_1[column_name]
cheeropowerplus5_pdnego_soc10_home_voltage_2 = cheeropowerplus5_pdnego_soc10_home_2[column_name]
cheeropowerplus5_pdnego_soc10_home_voltage_3 = cheeropowerplus5_pdnego_soc10_home_3[column_name]
cheeropowerplus5_pdnego_soc10_home_voltage_4 = cheeropowerplus5_pdnego_soc10_home_4[column_name]
cheeropowerplus5_pdnego_soc10_home_voltage_5 = cheeropowerplus5_pdnego_soc10_home_5[column_name]
cheeropowerplus5_pdnego_soc10_voltage = cheeropowerplus5_pdnego_soc10[column_name]
cheeropowerplus5_pdnego_soc20_voltage = cheeropowerplus5_pdnego_soc20[column_name]
cheeropowerplus5_pdnego_soc30_voltage = cheeropowerplus5_pdnego_soc30[column_name]
cheeropowerplus5_pdnego_soc40_voltage = cheeropowerplus5_pdnego_soc40[column_name]
cheeropowerplus5_pdnego_soc50_voltage = cheeropowerplus5_pdnego_soc50[column_name]
cheeropowerplus5_pdnego_soc60_voltage = cheeropowerplus5_pdnego_soc60[column_name]
cheeropowerplus5_pdnego_soc70_voltage = cheeropowerplus5_pdnego_soc70[column_name]
cheeropowerplus5_pdnego_soc80_voltage = cheeropowerplus5_pdnego_soc80[column_name]
cheeropowerplus5_pdnego_soc90_voltage = cheeropowerplus5_pdnego_soc90[column_name]
cheeropowerplus5_pdnego_soc100_voltage = cheeropowerplus5_pdnego_soc100[column_name]

column_name = 'VBUS Wattage[W]' 
cheeropowerplus5_pdnego_soc10_home_wattage_1 = cheeropowerplus5_pdnego_soc10_home_1[column_name]
cheeropowerplus5_pdnego_soc10_home_wattage_2 = cheeropowerplus5_pdnego_soc10_home_2[column_name]
cheeropowerplus5_pdnego_soc10_home_wattage_3 = cheeropowerplus5_pdnego_soc10_home_3[column_name]
cheeropowerplus5_pdnego_soc10_home_wattage_4 = cheeropowerplus5_pdnego_soc10_home_4[column_name]
cheeropowerplus5_pdnego_soc10_home_wattage_5 = cheeropowerplus5_pdnego_soc10_home_5[column_name]
cheeropowerplus5_pdnego_soc10_wattage = cheeropowerplus5_pdnego_soc10[column_name]
cheeropowerplus5_pdnego_soc20_wattage = cheeropowerplus5_pdnego_soc20[column_name]
cheeropowerplus5_pdnego_soc30_wattage = cheeropowerplus5_pdnego_soc30[column_name]
cheeropowerplus5_pdnego_soc40_wattage = cheeropowerplus5_pdnego_soc40[column_name]
cheeropowerplus5_pdnego_soc50_wattage = cheeropowerplus5_pdnego_soc50[column_name]
cheeropowerplus5_pdnego_soc60_wattage = cheeropowerplus5_pdnego_soc60[column_name]
cheeropowerplus5_pdnego_soc70_wattage = cheeropowerplus5_pdnego_soc70[column_name]
cheeropowerplus5_pdnego_soc80_wattage = cheeropowerplus5_pdnego_soc80[column_name]
cheeropowerplus5_pdnego_soc90_wattage = cheeropowerplus5_pdnego_soc90[column_name]
cheeropowerplus5_pdnego_soc100_wattage = cheeropowerplus5_pdnego_soc100[column_name]

# %% [markdown]
# ## Comparison method

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(cheeropowerplus5_15s_soc10_home_current_1, label='cheero Power Plus 5')
axs[0].plot(cheeropowerplus5_15s_soc10_home_current_2, label='cheero Power Plus 5')
axs[0].plot(cheeropowerplus5_15s_soc10_home_current_3, label='cheero Power Plus 5')
axs[0].plot(cheeropowerplus5_15s_soc10_home_current_4, label='cheero Power Plus 5')
axs[0].plot(cheeropowerplus5_15s_soc10_home_current_5, label='cheero Power Plus 5')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(cheeropowerplus5_15s_soc10_home_voltage_1, label='cheero Power Plus 5')
axs[1].plot(cheeropowerplus5_15s_soc10_home_voltage_2, label='cheero Power Plus 5')
axs[1].plot(cheeropowerplus5_15s_soc10_home_voltage_3, label='cheero Power Plus 5')
axs[1].plot(cheeropowerplus5_15s_soc10_home_voltage_4, label='cheero Power Plus 5')
axs[1].plot(cheeropowerplus5_15s_soc10_home_voltage_5, label='cheero Power Plus 5')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(cheeropowerplus5_15s_soc10_home_wattage_1, label='cheero Power Plus 5')
axs[2].plot(cheeropowerplus5_15s_soc10_home_wattage_2, label='cheero Power Plus 5')
axs[2].plot(cheeropowerplus5_15s_soc10_home_wattage_3, label='cheero Power Plus 5')
axs[2].plot(cheeropowerplus5_15s_soc10_home_wattage_4, label='cheero Power Plus 5')
axs[2].plot(cheeropowerplus5_15s_soc10_home_wattage_5, label='cheero Power Plus 5')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/cheeroPowerPlus5#1/15s/vghub_15s_cheeropowerplus5#1_soc10_home_CVW.png')
plt.show()

# %% [markdown]
# ## Proposed method

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(cheeropowerplus5_pdnego_soc10_home_current_1, label='cheero Power Plus 5')
axs[0].plot(cheeropowerplus5_pdnego_soc10_home_current_2, label='cheero Power Plus 5')
axs[0].plot(cheeropowerplus5_pdnego_soc10_home_current_3, label='cheero Power Plus 5')
axs[0].plot(cheeropowerplus5_pdnego_soc10_home_current_4, label='cheero Power Plus 5')
axs[0].plot(cheeropowerplus5_pdnego_soc10_home_current_5, label='cheero Power Plus 5')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(cheeropowerplus5_pdnego_soc10_home_voltage_1, label='cheero Power Plus 5')
axs[1].plot(cheeropowerplus5_pdnego_soc10_home_voltage_2, label='cheero Power Plus 5')
axs[1].plot(cheeropowerplus5_pdnego_soc10_home_voltage_3, label='cheero Power Plus 5')
axs[1].plot(cheeropowerplus5_pdnego_soc10_home_voltage_4, label='cheero Power Plus 5')
axs[1].plot(cheeropowerplus5_15s_soc10_home_voltage_5, label='cheero Power Plus 5')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(cheeropowerplus5_pdnego_soc10_home_wattage_1, label='cheero Power Plus 5')
axs[2].plot(cheeropowerplus5_pdnego_soc10_home_wattage_2, label='cheero Power Plus 5')
axs[2].plot(cheeropowerplus5_pdnego_soc10_home_wattage_3, label='cheero Power Plus 5')
axs[2].plot(cheeropowerplus5_pdnego_soc10_home_wattage_4, label='cheero Power Plus 5')
axs[2].plot(cheeropowerplus5_pdnego_soc10_home_wattage_5, label='cheero Power Plus 5')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/cheeroPowerPlus5#1/PDNego/vghub_pdnego_cheeropowerplus5#1_soc10_home_CVW.png')
plt.show()

# %% [markdown]
# ## Comparison method: SOC (State Of Charge) comparison

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(cheeropowerplus5_15s_soc10_current, label='SOC 10%')
axs[0].plot(cheeropowerplus5_15s_soc20_current, label='SOC 20%')
axs[0].plot(cheeropowerplus5_15s_soc30_current, label='SOC 30%')
axs[0].plot(cheeropowerplus5_15s_soc40_current, label='SOC 40%')
axs[0].plot(cheeropowerplus5_15s_soc50_current, label='SOC 50%')
axs[0].plot(cheeropowerplus5_15s_soc60_current, label='SOC 60%')
axs[0].plot(cheeropowerplus5_15s_soc70_current, label='SOC 70%')
axs[0].plot(cheeropowerplus5_15s_soc80_current, label='SOC 80%')
axs[0].plot(cheeropowerplus5_15s_soc90_current, label='SOC 90%')
axs[0].plot(cheeropowerplus5_15s_soc100_current, label='SOC 100%')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(cheeropowerplus5_15s_soc10_voltage, label='SOC 10%')
axs[1].plot(cheeropowerplus5_15s_soc20_voltage, label='SOC 20%')
axs[1].plot(cheeropowerplus5_15s_soc30_voltage, label='SOC 30%')
axs[1].plot(cheeropowerplus5_15s_soc40_voltage, label='SOC 40%')
axs[1].plot(cheeropowerplus5_15s_soc50_voltage, label='SOC 50%')
axs[1].plot(cheeropowerplus5_15s_soc60_voltage, label='SOC 60%')
axs[1].plot(cheeropowerplus5_15s_soc70_voltage, label='SOC 70%')
axs[1].plot(cheeropowerplus5_15s_soc80_voltage, label='SOC 80%')
axs[1].plot(cheeropowerplus5_15s_soc90_voltage, label='SOC 90%')
axs[1].plot(cheeropowerplus5_15s_soc100_voltage, label='SOC 100%')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(cheeropowerplus5_15s_soc10_wattage, label='SOC 10%')
axs[2].plot(cheeropowerplus5_15s_soc20_wattage, label='SOC 20%')
axs[2].plot(cheeropowerplus5_15s_soc30_wattage, label='SOC 30%')
axs[2].plot(cheeropowerplus5_15s_soc40_wattage, label='SOC 40%')
axs[2].plot(cheeropowerplus5_15s_soc50_wattage, label='SOC 50%')
axs[2].plot(cheeropowerplus5_15s_soc60_wattage, label='SOC 60%')
axs[2].plot(cheeropowerplus5_15s_soc70_wattage, label='SOC 70%')
axs[2].plot(cheeropowerplus5_15s_soc80_wattage, label='SOC 80%')
axs[2].plot(cheeropowerplus5_15s_soc90_wattage, label='SOC 90%')
axs[2].plot(cheeropowerplus5_15s_soc100_wattage, label='SOC 100%')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/cheeroPowerPlus5#1/15s/vghub_15s_cheeropowerplus5#1_soc_home_CVW.png')
plt.show()

# %% [markdown]
# ## Proposed method: SOC (State Of Charge) comparison

# %%
plt.rcParams['font.family'] = 'Arial'

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

axs[0].plot(cheeropowerplus5_pdnego_soc10_current, label='SOC 10%')
axs[0].plot(cheeropowerplus5_pdnego_soc20_current, label='SOC 20%')
axs[0].plot(cheeropowerplus5_pdnego_soc30_current, label='SOC 30%')
axs[0].plot(cheeropowerplus5_pdnego_soc40_current, label='SOC 40%')
axs[0].plot(cheeropowerplus5_pdnego_soc50_current, label='SOC 50%')
axs[0].plot(cheeropowerplus5_pdnego_soc60_current, label='SOC 60%')
axs[0].plot(cheeropowerplus5_pdnego_soc70_current, label='SOC 70%')
axs[0].plot(cheeropowerplus5_pdnego_soc80_current, label='SOC 80%')
axs[0].plot(cheeropowerplus5_pdnego_soc90_current, label='SOC 90%')
axs[0].plot(cheeropowerplus5_pdnego_soc100_current, label='SOC 100%')
axs[0].set_xlabel('Time (ms)', fontweight='bold')
axs[0].set_ylabel('VBUS Current (A)', fontweight='bold')
legend = axs[0].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[0].grid(True)

axs[1].plot(cheeropowerplus5_pdnego_soc10_voltage, label='SOC 10%')
axs[1].plot(cheeropowerplus5_pdnego_soc20_voltage, label='SOC 20%')
axs[1].plot(cheeropowerplus5_pdnego_soc30_voltage, label='SOC 30%')
axs[1].plot(cheeropowerplus5_pdnego_soc40_voltage, label='SOC 40%')
axs[1].plot(cheeropowerplus5_pdnego_soc50_voltage, label='SOC 50%')
axs[1].plot(cheeropowerplus5_pdnego_soc60_voltage, label='SOC 60%')
axs[1].plot(cheeropowerplus5_pdnego_soc70_voltage, label='SOC 70%')
axs[1].plot(cheeropowerplus5_pdnego_soc80_voltage, label='SOC 80%')
axs[1].plot(cheeropowerplus5_pdnego_soc90_voltage, label='SOC 90%')
axs[1].plot(cheeropowerplus5_pdnego_soc100_voltage, label='SOC 100%')
axs[1].set_xlabel('Time (ms)', fontweight='bold')
axs[1].set_ylabel('VBUS Voltage (V)', fontweight='bold')
legend = axs[1].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[1].grid(True)

axs[2].plot(cheeropowerplus5_pdnego_soc10_wattage, label='SOC 10%')
axs[2].plot(cheeropowerplus5_pdnego_soc20_wattage, label='SOC 20%')
axs[2].plot(cheeropowerplus5_pdnego_soc30_wattage, label='SOC 30%')
axs[2].plot(cheeropowerplus5_pdnego_soc40_wattage, label='SOC 40%')
axs[2].plot(cheeropowerplus5_pdnego_soc50_wattage, label='SOC 50%')
axs[2].plot(cheeropowerplus5_pdnego_soc60_wattage, label='SOC 60%')
axs[2].plot(cheeropowerplus5_pdnego_soc70_wattage, label='SOC 70%')
axs[2].plot(cheeropowerplus5_pdnego_soc80_wattage, label='SOC 80%')
axs[2].plot(cheeropowerplus5_pdnego_soc90_wattage, label='SOC 90%')
axs[2].plot(cheeropowerplus5_pdnego_soc100_wattage, label='SOC 100%')
axs[2].set_xlabel('Time (ms)', fontweight='bold')
axs[2].set_ylabel('VBUS Wattage (W)', fontweight='bold')
legend = axs[2].legend()
for text in legend.get_texts():
    text.set_fontweight('bold')
axs[2].grid(True)

plt.tight_layout()
plt.savefig('./Images/cheeroPowerPlus5#1/PDNego/vghub_pdnego_cheeropowerplus5#1_soc_home_CVW.png')
plt.show()
