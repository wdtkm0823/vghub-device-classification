# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pixel3a_15s_soc10_home_1 = pd.read_csv('csv/googlepixel3a#1/output_vghub_15s_data_3_pixel3a#1_soc10_home_1.csv')
pixel3a_15s_soc10_home_2 = pd.read_csv('csv/googlepixel3a#1/output_vghub_15s_data_3_pixel3a#1_soc10_home_2.csv')
pixel3a_15s_soc10_home_3 = pd.read_csv('csv/googlepixel3a#1/output_vghub_15s_data_3_pixel3a#1_soc10_home_3.csv')
pixel3a_15s_soc10_home_4 = pd.read_csv('csv/googlepixel3a#1/output_vghub_15s_data_3_pixel3a#1_soc10_home_4.csv')
pixel3a_15s_soc10_home_5 = pd.read_csv('csv/googlepixel3a#1/output_vghub_15s_data_3_pixel3a#1_soc10_home_5.csv')

# %%
column_name = 'VBUS Current[A]' 
pixel3a_15s_soc10_home_current_1 = pixel3a_15s_soc10_home_1[column_name]
pixel3a_15s_soc10_home_current_2 = pixel3a_15s_soc10_home_2[column_name]
pixel3a_15s_soc10_home_current_3 = pixel3a_15s_soc10_home_3[column_name]
pixel3a_15s_soc10_home_current_4 = pixel3a_15s_soc10_home_4[column_name]
pixel3a_15s_soc10_home_current_5 = pixel3a_15s_soc10_home_5[column_name]

# グラフのプロット
plt.plot(pixel3a_15s_soc10_home_current_1, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_current_2, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_current_3, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_current_4, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_current_5, label='Google Pixel 3a #1')

# グラフの設定
plt.xlabel('Time (ms)')
plt.ylabel('VBUS Current (A)')
plt.legend()
plt.grid(True)
plt.tight_layout()

# グラフの表示
plt.show()

# %%
column_name = 'VBUS Voltage[V]' 
pixel3a_15s_soc10_home_voltage_1 = pixel3a_15s_soc10_home_1[column_name]
pixel3a_15s_soc10_home_voltage_2 = pixel3a_15s_soc10_home_2[column_name]
pixel3a_15s_soc10_home_voltage_3 = pixel3a_15s_soc10_home_3[column_name]
pixel3a_15s_soc10_home_voltage_4 = pixel3a_15s_soc10_home_4[column_name]
pixel3a_15s_soc10_home_voltage_5 = pixel3a_15s_soc10_home_5[column_name]

# グラフのプロット
plt.plot(pixel3a_15s_soc10_home_voltage_1, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_voltage_2, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_voltage_3, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_voltage_4, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_voltage_5, label='Google Pixel 3a #1')

# グラフの設定
plt.xlabel('Time (ms)')
plt.ylabel('VBUS Voltage (V)')
plt.legend()
plt.grid(True)
plt.tight_layout()

# グラフの表示
plt.show()

# %%
column_name = 'VBUS Wattage[W]' 
pixel3a_15s_soc10_home_wattage_1 = pixel3a_15s_soc10_home_1[column_name]
pixel3a_15s_soc10_home_wattage_2 = pixel3a_15s_soc10_home_2[column_name]
pixel3a_15s_soc10_home_wattage_3 = pixel3a_15s_soc10_home_3[column_name]
pixel3a_15s_soc10_home_wattage_4 = pixel3a_15s_soc10_home_4[column_name]
pixel3a_15s_soc10_home_wattage_5 = pixel3a_15s_soc10_home_5[column_name]

# グラフのプロット
plt.plot(pixel3a_15s_soc10_home_wattage_1, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_wattage_2, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_wattage_3, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_wattage_4, label='Google Pixel 3a #1')
plt.plot(pixel3a_15s_soc10_home_wattage_5, label='Google Pixel 3a #1')

# グラフの設定
plt.xlabel('Time (ms)')
plt.ylabel('VBUS Wattage (W)')
plt.legend()
plt.grid(True)
plt.tight_layout()

# グラフの表示
plt.show()
